# %%
import pandas as pd
import joblib
import sklearn


modele = joblib.load("models/agent_viralite_model.pkl")
# Out:
# c:\Users\jpouc\Documents\programmation\datathon\venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\jpouc\Documents\programmation\datathon\venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
features = {
            "X Followers": 20,
            "verified": False,
            "X Posts": 500,
            "nb_hashtags": 3,
            "longueur": 200
        }
        

modele.predict([features])
print("Prediction:", modele.predict([features]))
# Out:
# c:\Users\jpouc\Documents\programmation\datathon\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       6             "longueur": 200
#       7         }
#       8
#       9
# ---> 10 modele.predict([features])
#      11 print("Prediction:", modele.predict([features]))
#
# File c:\Users\jpouc\Documents\programmation\datathon\venv\Lib\site-packages\sklearn\pipeline.py:796, in Pipeline.predict(self, X, **params)
#     794 if not _routing_enabled():
#     795     for _, name, transform in self._iter(with_final=False):
# --> 796         Xt = transform.transform(Xt)
#     797     return self.steps[-1][1].predict(Xt, **params)
#     799 # metadata routing enabled
#
# ...
